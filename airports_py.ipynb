# %% [markdown]
# # Аэропорты все по всему миру
# ## координаты, все данные по ним, высота высокогорные международные аэропорты

# %%
import numpy as np
import pandas as pd
airports = pd.read_csv('C:/Users/student/Desktop/airports.csv',names = ['Airport ID','Name','City','Country','IATA','ICAO','Latitude','Longitude','Altitude','Timezone','DST','Tz_database_time_zone','Type','Source'])
airports.head()
routes = pd.read_csv('C:/Users/student/Desktop/routes.csv',names = ['Airline','Airport ID','Source airport','Source airport ID','Destination airport','Destination airport ID','Codeshare','Stops','Equipment'])
routes.head()
airlines = pd.read_csv('C:/Users/student/Desktop/airlines.csv',names = ['Airline ID','Name','Alias','IATA','ICAO','Callsign','Country','Active'])
routes
# Out:
#       Airline Airport ID Source airport Source airport ID Destination airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# 5          2B        410            DME              4029                 KZN
# 6          2B        410            DME              4029                 NBC
# 7          2B        410            DME              4029                 TGK
# 8          2B        410            DME              4029                 UUA
# 9          2B        410            EGO              6156                 KGD
# 10         2B        410            EGO              6156                 KZN
# ...

# %%
airlines
# Out:
#       Airline ID                                          Name  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# 5              5                               213 Flight Unit
# 6              6                 223 Flight Unit State Airline
# 7              7                             224th Flight Unit
# 8              8                                   247 Jet Ltd
# 9              9                                   3D Aviation
# 10            10                                   40-Mile Air
# 11            11                                        4D Air
# 12            12                        611897 Alberta Limited
# 13            13                              Ansett Australia
# ...

# %%
airports[airports['Altitude'] >= 14000]['IATA']
# Out:
# 5000    BPX
# 5819    NGQ
# Name: IATA, dtype: object

# %%
ports = routes[(routes['Source airport']=='BPX')|(routes['Source airport']=='NGQ')|(routes['Destination airport']=='NGQ')|(routes['Destination airport']=='NGQ')]
ports = np.unique(ports.Airline.values)
ports
# Out:
# array(['CA', 'MU', 'TV', 'ZH'], dtype=object)

# %%
np.array([airlines[airlines['IATA']==i]['Name'].values for i in ports ]).T
# Out:
# array([['Air China', 'China Eastern Airlines', 'Virgin Express',
#         'Shenzhen Airlines']], dtype=object)
