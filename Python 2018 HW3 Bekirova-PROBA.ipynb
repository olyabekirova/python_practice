# %%
#Отобрать аэропорты Австралии, из которых можно улететь за пределы Австралии
#Посчитать для каждого аэропорта сколько и для какого города я могу улететь
#Найти несовпадения табличек routes и airports
#Упорядочить страны по алфавиту
#Сгруппировать страны по континентам
# Out:
# C:\Users\oabek\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
import numpy as np
import pandas as pd
from numpy import nan as NA

# %%
#Подгружаем данные

airport = pd.read_csv('airports.csv', names = ['ID', 'Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz database time zone', 'Type', 'Source'])
routes = pd.read_csv('routes.csv', names = ['Airline', 'AirlineID', 'SourceAirport', 'Source Airport ID', 'DestinationAirport', 'Destination Airport ID', 'Codeshare', 'Stops', 'Equipment' ])

# %%
#Отбираем из таблички airport аэропорт Австралии
#Важно! К Австралии относится не только сам остров Австралия, но и внешние территории, из них на 3 островах есть аэропорты
#В табличке airport в колонке country для них не Australia, а их названия: 
#Norfolk Island, Cocos (Keeling) Islands, Christmas Island
#Поэтому отбираем их тоже

australia = ['Australia', 'Norfolk Island', 'Cocos (Keeling) Islands', 'Christmas Island']
aus_air = airport[airport['Country'].isin(australia)]

# %%
#Проверяем есть ли Na в IATA
icao_air = aus_air[aus_air['IATA']=='\\N']
icao_air
# Out:
#          ID                            Name                 City    Country  \
# 3113   3317    Brisbane Archerfield Airport             Brisbane  Australia
# 3130   3335             RAAF Base East Sale            East Sale  Australia
# 3135   3340  RAAF Williams, Point Cook Base           Point Cook  Australia
# 3137   3343             RAAF Base Edinburgh            Edinburgh  Australia
# 3144   3350      Adelaide Parafield Airport             Adelaide  Australia
# 3154   3360              RAAF Base Richmond             Richmond  Australia
# 5182   6860           Bungle Bungle Airport        Bungle Bungle  Australia
# 5199   6896              RAAF Base Amberley             Amberley  Australia
# 5201   6898    RAAF Williams, Laverton Base             Laverton  Australia
# 5210   6914                RAAF Base Pearce                Perth  Australia
# 5211   6915                 Bendigo Airport              Bendigo  Australia
# 5359   7129                 Ballera Airport              Ballera  Australia
# 5360   7130           Gatton Campus Airport               Gatton  Australia
# 5747   7811               Redcliffe Airport             Rothwell  Australia
# 5791   7879          Phillip Island Airport       Phillip Island  Australia
# 6052   8350               Warburton Airport  Warburton Community  Australia
# 6053   8351               Cunderdin Airport            Cunderdin  Australia
# 6055   8353                 Forrest Airport              Forrest  Australia
# 6056   8354                Ballarat Airport             Ballarat  Australia
# 6079   8406                  Yarram Airport               Yarram  Australia
# 6106   8472          Yalata Mission Airport               Yalata  Australia
# 6110   8476                 Wyndham Airport              Wyndham  Australia
# 6217   8696                Beverley Airport            Mine Site  Australia
# 6281   8822            Mount Garnet Airport         Mount Garnet  Australia
# 6363   9001                 Ivanhoe Airport              Ivanhoe  Australia
# 6364   9002                Menindee Airport             Menindee  Australia
# 6365   9004               Pooncarie Airport            Pooncarie  Australia
# 6366   9006                   Tilpa Airport                Tilpa  Australia
# 6432   9207              Warnervale Airport   Warnervale Airport  Australia
# 6520   9542               Coral Bay Airport            Coral Bay  Australia
# 6569   9818                Lilydale Airport             Lilydale  Australia
# 6653  10140                Atherton Airport             Atherton  Australia
# 6682  10370                  Kadina Airport               Kadina  Australia
# 6728  11038         Flinders Island Airport             Elliston  Australia
# 6821  11272           Murray Bridge Airport        Murray Bridge  Australia
# 6858  11673           William Creek Airport        William Creek  Australia
#
#      IATA  ICAO   Latitude   Longitude  Altitude Timezone DST  \
# 3113   \N  YBAF -27.570299  153.007996        63       10   O
# 3130   \N  YMES -38.098900  147.149002        23       10   O
# 3135   \N  YMPC -37.932201  144.753006        14       10   O
# 3137   \N  YPED -34.702499  138.621002        67      9.5   O
# 3144   \N  YPPF -34.793301  138.632996        57      9.5   O
# 3154   \N  YSRI -33.600601  150.781006        67       10   O
# 5182   \N  YBUU -17.545300  128.307007         0        8   U
# 5199   \N  YAMB -27.640600  152.712006        91       10   O
# 5201   \N  YLVT -37.863602  144.746002        18       10   O
# 5210   \N  YPEA -31.667801  116.014999       149        8   O
# 5211   \N  YBDG -36.739399  144.330002       705       10   U
# 5359   \N  YLLE -27.405633  141.809458       385       10   N
# 5360   \N  YGAT -27.560406  152.340460         0       10   N
# 5747   \N  YRED -27.206699  153.067993         2       10   U
# 5791   \N  YPID -38.523300  145.326996        13       10   O
# 6052   \N  YWBR -26.128300  126.583000      1500        8   O
# 6053   \N  YCUN -31.622200  117.217003       705        8   O
# 6055   \N  YFRT -30.838100  128.115005       511        8   O
# 6056   \N  YBLT -37.511700  143.791000      1433       10   O
# 6079   \N  YYRM -38.566700  146.755005        15       10   O
# 6106   \N  YYTA -31.470600  131.824997         0      9.5   O
# 6110   \N  YWYM -15.511400  128.153000        14        8   U
# 6217   \N  YBEE -30.186701  139.557999       116      9.5   O
# 6281   \N  YMRT -17.700001  145.149994       657       10   U
# 6363   \N  YIVO -32.883301  144.309998       330       10   O
# 6364   \N  YMED -32.366699  142.404999         0       10   O
# 6365   \N  YPCE -33.366699  142.587997        50       10   O
# 6366   \N  YTLP -30.933300  144.417007         0       10   O
# 6432   \N  YWVA -33.240278  151.429722        25       10   U
# 6520   \N  YCOY -23.129999  113.777000         5        8   O
# 6569   \N  YLIL -37.691700  145.367004        76       10   O
# 6653   \N  YATN -17.261700  145.514999      2450       10   O
# 6682   \N  YKDI -33.976700  137.660004        42      9.5   O
# 6728   \N  YFLS -33.730989  134.501000         0      9.5   O
# 6821   \N  YMBD -35.066700  139.227005        55       10   O
# 6858   \N  YWMC -28.906700  136.341995        91      9.5   U
#
#      Tz database time zone     Type       Source
# 3113    Australia/Brisbane  airport  OurAirports
# 3130      Australia/Hobart  airport  OurAirports
# 3135      Australia/Hobart  airport  OurAirports
# 3137    Australia/Adelaide  airport  OurAirports
# 3144    Australia/Adelaide  airport  OurAirports
# 3154      Australia/Sydney  airport  OurAirports
# 5182       Australia/Perth  airport  OurAirports
# 5199    Australia/Brisbane  airport  OurAirports
# 5201      Australia/Hobart  airport  OurAirports
# 5210       Australia/Perth  airport  OurAirports
# 5211      Australia/Hobart  airport  OurAirports
# 5359    Australia/Brisbane  airport  OurAirports
# 5360    Australia/Brisbane  airport  OurAirports
# 5747    Australia/Brisbane  airport  OurAirports
#      IATA  ICAO   Latitude   Longitude  Altitude Timezone DST  \
# 3113   \N  YBAF -27.570299  153.007996        63       10   O
# 3130   \N  YMES -38.098900  147.149002        23       10   O
# 3135   \N  YMPC -37.932201  144.753006        14       10   O
# 3137   \N  YPED -34.702499  138.621002        67      9.5   O
# 3144   \N  YPPF -34.793301  138.632996        57      9.5   O
# 3154   \N  YSRI -33.600601  150.781006        67       10   O
# 5182   \N  YBUU -17.545300  128.307007         0        8   U
# 5199   \N  YAMB -27.640600  152.712006        91       10   O
# 5201   \N  YLVT -37.863602  144.746002        18       10   O
# 5210   \N  YPEA -31.667801  116.014999       149        8   O
# 5211   \N  YBDG -36.739399  144.330002       705       10   U
# 5359   \N  YLLE -27.405633  141.809458       385       10   N
# 5360   \N  YGAT -27.560406  152.340460         0       10   N
# 5747   \N  YRED -27.206699  153.067993         2       10   U
# 5791   \N  YPID -38.523300  145.326996        13       10   O
# 6052   \N  YWBR -26.128300  126.583000      1500        8   O
# 6053   \N  YCUN -31.622200  117.217003       705        8   O
# 6055   \N  YFRT -30.838100  128.115005       511        8   O
# 6056   \N  YBLT -37.511700  143.791000      1433       10   O
# 6079   \N  YYRM -38.566700  146.755005        15       10   O
# 6106   \N  YYTA -31.470600  131.824997         0      9.5   O
# 6110   \N  YWYM -15.511400  128.153000        14        8   U
# 6217   \N  YBEE -30.186701  139.557999       116      9.5   O
# 6281   \N  YMRT -17.700001  145.149994       657       10   U
# 6363   \N  YIVO -32.883301  144.309998       330       10   O
# 6364   \N  YMED -32.366699  142.404999         0       10   O
# 6365   \N  YPCE -33.366699  142.587997        50       10   O
# 6366   \N  YTLP -30.933300  144.417007         0       10   O
# 6432   \N  YWVA -33.240278  151.429722        25       10   U
# 6520   \N  YCOY -23.129999  113.777000         5        8   O
# 6569   \N  YLIL -37.691700  145.367004        76       10   O
# 6653   \N  YATN -17.261700  145.514999      2450       10   O
# 6682   \N  YKDI -33.976700  137.660004        42      9.5   O
# 6728   \N  YFLS -33.730989  134.501000         0      9.5   O
# 6821   \N  YMBD -35.066700  139.227005        55       10   O
# 6858   \N  YWMC -28.906700  136.341995        91      9.5   U
#
#      Tz database time zone     Type       Source
# 3113    Australia/Brisbane  airport  OurAirports
# 3130      Australia/Hobart  airport  OurAirports
# 3135      Australia/Hobart  airport  OurAirports
# 3137    Australia/Adelaide  airport  OurAirports
# 3144    Australia/Adelaide  airport  OurAirports
# 3154      Australia/Sydney  airport  OurAirports
# 5182       Australia/Perth  airport  OurAirports
# 5199    Australia/Brisbane  airport  OurAirports
# 5201      Australia/Hobart  airport  OurAirports
# 5210       Australia/Perth  airport  OurAirports
# 5211      Australia/Hobart  airport  OurAirports
# 5359    Australia/Brisbane  airport  OurAirports
# 5360    Australia/Brisbane  airport  OurAirports
# 5747    Australia/Brisbane  airport  OurAirports
# 5791      Australia/Hobart  airport  OurAirports
# 6052       Australia/Perth  airport  OurAirports
# 6053       Australia/Perth  airport  OurAirports
# 6055       Australia/Perth  airport  OurAirports
# 6056      Australia/Hobart  airport  OurAirports
# 6079      Australia/Hobart  airport  OurAirports
# 6106    Australia/Adelaide  airport  OurAirports
# 6110       Australia/Perth  airport  OurAirports
# 6217    Australia/Adelaide  airport  OurAirports
# 6281    Australia/Brisbane  airport  OurAirports
# 6363      Australia/Sydney  airport  OurAirports
# 6364      Australia/Sydney  airport  OurAirports
# 6365      Australia/Sydney  airport  OurAirports
# 6366      Australia/Sydney  airport  OurAirports
# 6432      Australia/Sydney  airport  OurAirports
# 6520       Australia/Perth  airport  OurAirports
# 6569      Australia/Hobart  airport  OurAirports
# 6653                    \N  airport  OurAirports
# 6682                    \N  airport  OurAirports
# 6728                    \N  airport  OurAirports
# 6821                    \N  airport  OurAirports
# 6858                    \N  airport  OurAirports

# %%
#Na есть, но для них для всех есть ID и ICAO, проверим есть ли в routes по ним данные
#Проверить по ID
aus_id = np.array(icao_air['ID'].unique())
aus_id2 = np.array(['{:.0f}'.format(x) for x in aus_id])
routes[routes['Source Airport ID'].isin(aus_id2)]

#С такими ID нет
# Out:
# Empty DataFrame
# Columns: [Airline, AirlineID, SourceAirport, Source Airport ID, DestinationAirport, Destination Airport ID, Codeshare, Stops, Equipment]
# Index: []

# %%
#Проверка по ICAO
#В routes вообще нет  4 буквенных кодов
routes[routes['SourceAirport'].str.len()==4]
# Out:
# Empty DataFrame
# Columns: [Airline, AirlineID, SourceAirport, Source Airport ID, DestinationAirport, Destination Airport ID, Codeshare, Stops, Equipment]
# Index: []

# %%
routes[routes['DestinationAirport'].str.len()==4]
# Out:
# Empty DataFrame
# Columns: [Airline, AirlineID, SourceAirport, Source Airport ID, DestinationAirport, Destination Airport ID, Codeshare, Stops, Equipment]
# Index: []

# %%
#Поэтому можем заменить их на Nan и рабоать дальше без них
aus_air2 = aus_air.replace('\\N',NA)
aus_air2 = aus_air2[aus_air2['IATA'].str.len()==3]
aus_air2.count()
# Out:
# ID                       263
# Name                     263
# City                     233
# Country                  263
# IATA                     263
# ICAO                     263
# Latitude                 263
# Longitude                263
# Altitude                 263
# Timezone                 227
# DST                      227
# Tz database time zone    214
# Type                     263
# Source                   263
# dtype: int64

# %%
#Отберем IATA для австралийских аэропортов, чтобы по ним обобрать маршруты
iata = np.array(aus_air2['IATA'].unique())
iata
# Out:
# array(['ABM', 'ASP', 'BNE', 'OOL', 'CNS', 'CTL', 'ISA', 'MCY', 'MKY',
#        'PPP', 'ROK', 'TSV', 'WEI', 'AVV', 'ABX', 'MEB', 'HBA', 'LST',
#        'MBW', 'MEL', 'ADL', 'JAD', 'KTA', 'KGI', 'KNX', 'LEA', 'PHE',
#        'PER', 'UMR', 'XCH', 'BWU', 'CBR', 'CFS', 'CDU', 'DBO', 'NLK',
#        'SYD', 'TMW', 'WGA', 'EMD', 'DRW', 'AYQ', 'KGC', 'HVB', 'ARM',
#        'BKQ', 'BDB', 'HIS', 'THG', 'BNK', 'BME', 'NTL', 'ALH', 'GYL',
#        'AUU', 'BCI', 'BDD', 'BVI', 'BHQ', 'HTI', 'BEU', 'BRK', 'BUC',
#        'GIC', 'OKY', 'BQL', 'BHS', 'BLT', 'CVQ', 'CAZ', 'CPD', 'CNC',
#        'CNJ', 'CED', 'CTN', 'CMA', 'CNB', 'CUQ', 'OOM', 'DMD', 'NLF',
#        'DPO', 'ELC', 'EPR', 'FLS', 'GET', 'GLT', 'GTE', 'GFF', 'HID',
#        'HOK', 'MHU', 'HGD', 'JCK', 'KAX', 'KNS', 'KFG', 'KRB', 'KWM',
#        'KUG', 'LNO', 'LEL', 'LDH', 'IRG', 'LSY', 'LHG', 'LRE', 'LER',
#        'LVO', 'UBB', 'MKR', 'MIM', 'MGT', 'MNG', 'MCV', 'MQL', 'MMG',
#        'MRZ', 'MOV', 'MYA', 'MGB', 'ONG', 'MYI', 'MBH', 'NRA', 'NAA',
#        'NTN', 'ZNE', 'OLP', 'PUG', 'PMK', 'PBO', 'CCK', 'GOV', 'PKE',
#        'PLO', 'EDR', 'PQQ', 'PTJ', 'ULP', 'RAM', 'RMA', 'SGO', 'MJK',
#        'SBR', 'SRN', 'XTG', 'TCA', 'VCD', 'SYU', 'WNR', 'WYA', 'WUN',
#        'WOL', 'WIN', 'BWT', 'OKR', 'XMY', 'WME', 'GFN', 'OAG', 'TRO',
#        'GUL', 'CES', 'NSO', 'DGE', 'MTL', 'OKB', 'WSY', 'KTR', 'NOA',
#        'TWB', 'BWB', 'DRB', 'WGE', 'BRT', 'DKI', 'LZR', 'HLT', 'HCQ',
#        'FIZ', 'RVT', 'GEX', 'PEA', 'CDA', 'JAB', 'TEF', 'RMK', 'LGH',
#        'RTS', 'XMC', 'YUE', 'GKL', 'RPB', 'IFL', 'MOO', 'ONS', 'TDR',
#        'CCL', 'JHQ', 'SHT', 'TEM', 'GAH', 'WIO', 'BEO', 'BMP', 'BQB',
#        'IVR', 'GLI', 'KFE', 'COJ', 'BSJ', 'PXH', 'WTB', 'CMQ', 'WMB',
#        'RCM', 'DCN', 'BUY', 'CJF', 'BOX', 'PKT', 'GPN', 'HSM', 'SWH',
#        'DLK', 'XTO', 'ABH', 'ARY', 'BLN', 'BZD', 'BWQ', 'CVC', 'CWW',
#        'CYG', 'CMD', 'DRN', 'DNQ', 'DYA', 'ECH', 'FRB', 'GUH', 'HXX',
#        'HTU', 'KRA', 'KPS', 'KGY', 'TGN', 'MRG', 'RPM', 'QRM', 'PPI',
#        'SIO', 'SNB', 'SWC', 'TYB', 'TUM', 'WGT', 'WKB', 'QRR', 'SXE',
#        'WWY', 'NGA'], dtype=object)

# %%
#Отбираем маршруты
aus_abroad = routes[routes['SourceAirport'].isin(iata) & -routes['DestinationAirport'].isin(iata)]

#Коды IATA австралийских аэропортов, из которых можно улететь в другие страны
aus_abroad['SourceAirport'].unique()
# Out:
# array(['DRW', 'PER', 'MEL', 'SYD', 'BNE', 'CNS', 'ADL', 'OOL', 'NLK',
#        'PHE'], dtype=object)

# %%
#Направления куда летают
aus_abroad['DestinationAirport'].unique()
# Out:
# array(['SIN', 'CTU', 'CKG', 'AKL', 'LAX', 'CHC', 'DFW', 'HNL', 'YVR',
#        'DEL', 'HKG', 'AUH', 'BWN', 'TPE', 'PVG', 'PEK', 'POM', 'CAN',
#        'KUL', 'DXB', 'WLG', 'BKK', 'ZQN', 'CGK', 'NAN', 'SUV', 'DPS',
#        'HIR', 'KIX', 'NRT', 'HKT', 'LOP', 'ICN', 'SCL', 'BKI', 'MRU',
#        'NKG', 'SON', 'VLI', 'DUD', 'RAR', 'SFO', 'INU', 'MNL', 'RAB',
#        'NOU', 'ZBL', 'DIL', 'SGN', 'JNB', 'DOH', 'GUM', 'APW', 'TBU'],
#       dtype=object)

# %%
#Количество
len(aus_abroad['DestinationAirport'].unique())
# Out:
# 54

# %%
air = pd.DataFrame(airport, columns=['IATA','Country'])
air = air.rename(columns = {'IATA': 'DestinationAirport'})
aus = aus_abroad.merge(air, on = 'DestinationAirport', how = 'left')

#Cлили таблички, проверим все ли страны подтянулись
aus['Country'].unique()
# Out:
# array(['Singapore', 'China', 'New Zealand', 'United States', 'Canada',
#        'India', 'Hong Kong', 'United Arab Emirates', 'Brunei', 'Taiwan',
#        'Papua New Guinea', 'Malaysia', 'Thailand', 'Indonesia', 'Fiji',
#        'Solomon Islands', 'Japan', 'South Korea', 'Chile', 'Mauritius',
#        'Vanuatu', 'Cook Islands', 'Nauru', 'Philippines', 'New Caledonia',
#        nan, 'East Timor', 'Vietnam', 'South Africa', 'Guam', 'Samoa',
#        'Tonga'], dtype=object)

# %%
aus.count()
# Out:
# Airline                   335
# AirlineID                 335
# SourceAirport             335
# Source Airport ID         335
# DestinationAirport        335
# Destination Airport ID    335
# Codeshare                 119
# Stops                     335
# Equipment                 335
# Country                   332
# dtype: int64

# %%
aus[aus['Country'].isna()]
# Out:
#     Airline AirlineID SourceAirport Source Airport ID DestinationAirport  \
# 198      QF      4089           BNE              3320                ZBL
# 245      QR      4091           MEL              3339                DOH
# 246      QR      4091           PER              3351                DOH
#
#     Destination Airport ID Codeshare  Stops Equipment Country
# 198                     \N         Y      0   DH8 DH3     NaN
# 245                  11051       NaN      0       77W     NaN
# 246                  11051       NaN      0       77L     NaN

# %%
airport[airport['IATA']=='ZBL']
#В табличке airport нет этого аэропорта
#ZBL это австралийский аэропорт, поэтому проверили летают ли из него в другие страны
# Out:
# Empty DataFrame
# Columns: [ID, Name, City, Country, IATA, ICAO, Latitude, Longitude, Altitude, Timezone, DST, Tz database time zone, Type, Source]
# Index: []

# %%
routes[(routes['SourceAirport']=='ZBL') & -routes['DestinationAirport'].isin(iata)]
#Из него в другие страны не летают, но выкинем его из таблички aus, т.к. в Destination не должны быть австралийские аэропорты
# Out:
# Empty DataFrame
# Columns: [Airline, AirlineID, SourceAirport, Source Airport ID, DestinationAirport, Destination Airport ID, Codeshare, Stops, Equipment]
# Index: []

# %%
airport[airport['IATA']=='DOH']
#Это аэропорт Дохи(Катар) и его тоже не оказалось в табличке airport
# Out:
# Empty DataFrame
# Columns: [ID, Name, City, Country, IATA, ICAO, Latitude, Longitude, Altitude, Timezone, DST, Tz database time zone, Type, Source]
# Index: []

# %%
aus.loc[aus['DestinationAirport'] == 'DOH', 'Country'] = 'Qatar'
aus
# Out:
#     Airline AirlineID SourceAirport Source Airport ID DestinationAirport  \
# 0        3K      3021           DRW              3999                SIN
# 1        3K      3021           PER              3351                SIN
# 2        3U      4608           MEL              3339                CTU
# 3        3U      4608           SYD              3361                CKG
# 4        AA        24           BNE              3320                AKL
# 5        AA        24           BNE              3320                LAX
# 6        AA        24           MEL              3339                LAX
# 7        AA        24           SYD              3361                AKL
# 8        AA        24           SYD              3361                CHC
# 9        AA        24           SYD              3361                DFW
# 10       AA        24           SYD              3361                HNL
# 11       AA        24           SYD              3361                LAX
# 12       AB       214           BNE              3320                SIN
# 13       AC       330           SYD              3361                YVR
# 14       AI       218           MEL              3339                DEL
# 15       AI       218           SYD              3361                DEL
# 16       AY      2350           BNE              3320                HKG
# 17       AY      2350           CNS              3322                HKG
# 18       AY      2350           MEL              3339                HKG
# 19       AY      2350           SYD              3361                HKG
# 20       AZ       596           MEL              3339                AUH
# 21       AZ       596           SYD              3361                AUH
# 22       BA      1355           CNS              3322                HKG
# 23       BA      1355           SYD              3361                SIN
# 24       BI      4255           MEL              3339                BWN
# 25       BR      2091           BNE              3320                TPE
# 26       CA       751           MEL              3339                PVG
# 27       CA       751           SYD              3361                PEK
# 28       CA       751           SYD              3361                PVG
# 29       CG      1308           BNE              3320                POM
# ..      ...       ...           ...               ...                ...
# 305      VA      5360           MEL              3339                AKL
# 306      VA      5360           MEL              3339                AUH
# 307      VA      5360           MEL              3339                CHC
# 308      VA      5360           MEL              3339                DPS
# 309      VA      5360           MEL              3339                LAX
# 310      VA      5360           MEL              3339                NAN
# 311      VA      5360           MEL              3339                SIN
# 312      VA      5360           MEL              3339                WLG
# 313      VA      5360           OOL              3321                AKL
# 314      VA      5360           OOL              3321                CHC
# 315      VA      5360           PER              3351                AKL
# 316      VA      5360           PER              3351                DPS
# 317      VA      5360           PER              3351                HKT
# 318      VA      5360           PER              3351                SIN
# 319      VA      5360           PHE              3349                DPS
# 320      VA      5360           SYD              3361                AKL
# 321      VA      5360           SYD              3361                APW
# 322      VA      5360           SYD              3361                AUH
# 323      VA      5360           SYD              3361                CHC
# 324      VA      5360           SYD              3361                DPS
# 325      VA      5360           SYD              3361                HKG
# 326      VA      5360           SYD              3361                HNL
# 327      VA      5360           SYD              3361                LAX
# 328      VA      5360           SYD              3361                NAN
# 329      VA      5360           SYD              3361                SIN
# 330      VA      5360           SYD              3361                TBU
# 331      VA      5360           SYD              3361                WLG
# 332      VN      5309           MEL              3339                SGN
# 333      VN      5309           SYD              3361                SGN
# 334      VS      5347           SYD              3361                HKG
#
#     Destination Airport ID Codeshare  Stops        Equipment  \
# 0                     3316       NaN      0              320
# 1                     3316       NaN      0              320
# 2                     3395       NaN      0              330
# 3                     3393       NaN      0              330
# 4                     2006         Y      0              737
# 5                     3484         Y      0              744
# 6                     3484         Y      0              380
# 7                     2006         Y      0              737
# 8                     2009         Y      0              737
# 9                     3670         Y      0              744
# 10                    3728         Y      0              763
# 11                    3484         Y      0          744 380
# 12                    3316         Y      0              332
# 13                     156       NaN      0              77L
# 14                    3093       NaN      0              788
# 15                    3093       NaN      0              788
# 16                    3077       NaN      0              333
# 17                    3077         Y      0              333
# 18                    3077       NaN      0              333
# 19                    3077         Y      0          388 744
# 20                    2179         Y      0              77W
# 21                    2179         Y      0          77W 346
# 22                    3077         Y      0              333
# 23                    3316       NaN      0              777
# 24                    3272       NaN      0              787
# 25                    2276       NaN      0              332
# 26                    3406       NaN      0              330
# 27                    3364       NaN      0              330
# 28                    3406       NaN      0              330
# 29                       5       NaN      0              737
# ..                     ...       ...    ...              ...
# 305                   2006         Y      0      320 73H 773
# 306                   2179         Y      0              77W
# 307                   2009       NaN      0          320 73H
# 308                   3940       NaN      0              73H
# 309                   3484       NaN      0              77W
# 310                   1960         Y      0              73H
# 311                   3316         Y      0  77W 773 388 333
# 312                   2042       NaN      0              320
# 313                   2006         Y      0          73H 320
# 314                   2009       NaN      0              320
# 315                   2006         Y      0              772
# 316                   3940         Y      0              73H
# 317                   3179         Y      0              73H
# 318                   3316       NaN      0              772
# 319                   3940       NaN      0              100
# 320                   2006         Y      0  763 73H 320 772
# 321                   1969         Y      0              73H
# 322                   2179       NaN      0              77W
# 323                   2009       NaN      0              320
# 324                   3940         Y      0              73H
# 325                   3077         Y      0              346
# 326                   3728         Y      0              332
# 327                   3484       NaN      0              77W
# 328                   1960         Y      0              73H
# 329                   3316         Y      0      773 388 772
# 330                   1963         Y      0              73H
# 331                   2042       NaN      0              320
# 332                   3205       NaN      0              330
# 333                   3205       NaN      0              330
# 334                   3077       NaN      0              346
#
#                   Country
# 0               Singapore
# 1               Singapore
# 2                   China
# 3                   China
# 4             New Zealand
# 5           United States
# 6           United States
# 7             New Zealand
# 8             New Zealand
# 9           United States
# 10          United States
# 11          United States
# 12              Singapore
# 13                 Canada
# 14                  India
# 15                  India
# 16              Hong Kong
# 17              Hong Kong
# 18              Hong Kong
# 19              Hong Kong
# 20   United Arab Emirates
# 21   United Arab Emirates
# 22              Hong Kong
# 23              Singapore
# 24                 Brunei
# 25                 Taiwan
# 26                  China
# 27                  China
# 28                  China
# 29       Papua New Guinea
# ..                    ...
# 305           New Zealand
# 306  United Arab Emirates
# 307           New Zealand
# 308             Indonesia
# 309         United States
# 310                  Fiji
# 311             Singapore
# 312           New Zealand
# 313           New Zealand
# 314           New Zealand
# 315           New Zealand
# 316             Indonesia
# 317              Thailand
# 318             Singapore
# 319             Indonesia
# 320           New Zealand
# 321                 Samoa
# 322  United Arab Emirates
# 323           New Zealand
# 324             Indonesia
# 325             Hong Kong
# 326         United States
# 327         United States
# 328                  Fiji
# 329             Singapore
# 330                 Tonga
# 331           New Zealand
# 332               Vietnam
# 333               Vietnam
# 334             Hong Kong
#
# [335 rows x 10 columns]

# %%
aus_new = aus[aus['DestinationAirport'] != 'ZBL']
aus_new.count()
# Out:
# Airline                   334
# AirlineID                 334
# SourceAirport             334
# Source Airport ID         334
# DestinationAirport        334
# Destination Airport ID    334
# Codeshare                 118
# Stops                     334
# Equipment                 334
# Country                   334
# dtype: int64

# %%
final = aus_new.pivot_table(values = 'Airline', index=['Country','DestinationAirport'],  columns='SourceAirport', aggfunc='count')
final.sort_index()
# Out:
# SourceAirport                            ADL  BNE  CNS  DRW  MEL  NLK  OOL  \
# Country              DestinationAirport
# Brunei               BWN                 NaN  NaN  NaN  NaN  1.0  NaN  NaN
# Canada               YVR                 NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
aN  NaN  NaN  NaN  NaN  NaN  NaN
# Vanuatu              SON                 NaN  2.0  NaN  NaN  NaN  NaN  NaN
#                      VLI                 NaN  3.0  NaN  NaN  NaN  NaN  NaN
# Vietnam              SGN                 NaN  NaN  NaN  NaN  2.0  NaN  NaN
#
# SourceAirport                            PER  PHE   SYD
# Country              DestinationAirport
# Brunei               BWN                 NaN  NaN   NaN
# Canada               YVR                 NaN  NaN   1.0
# Chile                SCL                 NaN  NaN   2.0
# China                CAN                 1.0  NaN   1.0
#                      CKG                 NaN  NaN   1.0
#                      CTU                 NaN  NaN   NaN
#                      NKG                 NaN  NaN   2.0
#                      PEK                 NaN  NaN   1.0
#                      PVG                 NaN  NaN   4.0
# Cook Islands         RAR                 NaN  NaN   1.0
# East Timor           DIL                 NaN  NaN   NaN
# Fiji                 NAN                 NaN  NaN   4.0
#                      SUV                 NaN  NaN   1.0
# Guam                 GUM                 NaN  NaN   NaN
# Hong Kong            HKG                 1.0  NaN   5.0
# India                DEL                 NaN  NaN   1.0
# Indonesia            CGK                 2.0  NaN   2.0
#                      DPS                 5.0  1.0   3.0
#                      LOP                 1.0  NaN   NaN
# Japan                KIX                 NaN  NaN   NaN
#                      NRT                 NaN  NaN   2.0
# Malaysia             BKI                 1.0  NaN   NaN
#                      KUL                 2.0  NaN   2.0
# Mauritius            MRU                 1.0  NaN   NaN
# Nauru                INU                 NaN  NaN   NaN
# New Caledonia        NOU                 NaN  NaN   2.0
# New Zealand          AKL                 3.0  NaN  11.0
#                      CHC                 NaN  NaN   7.0
#                      DUD                 NaN  NaN   NaN
#                      WLG                 NaN  NaN   5.0
#                      ZQN                 NaN  NaN   3.0
# Papua New Guinea     POM                 NaN  NaN   2.0
#                      RAB                 NaN  NaN   NaN
# Philippines          MNL                 NaN  NaN   2.0
# Qatar                DOH                 1.0  NaN   NaN
# Samoa                APW                 NaN  NaN   1.0
# Singapore            SIN                 9.0  NaN   9.0
# Solomon Islands      HIR                 NaN  NaN   NaN
# South Africa         JNB                 2.0  NaN   2.0
# South Korea          ICN                 NaN  NaN   4.0
# Taiwan               TPE                 NaN  NaN   1.0
# Thailand             BKK                 2.0  NaN   4.0
#                      HKT                 1.0  NaN   1.0
# Tonga                TBU                 NaN  NaN   1.0
# United Arab Emirates AUH                 NaN  NaN   3.0
#                      DXB                 2.0  NaN   2.0
# United States        DFW                 NaN  NaN   2.0
#                      HNL                 NaN  NaN   5.0
#                      LAX                 NaN  NaN   6.0
#                      SFO                 NaN  NaN   2.0
# Vanuatu              SON                 NaN  NaN   NaN
#                      VLI                 NaN  NaN   2.0
# Vietnam              SGN                 NaN  NaN   2.0

# %%
#Объеденим по континентам, сначала посмотрим какой список стран
aus_new['Country'].unique()
# Out:
# array(['Singapore', 'China', 'New Zealand', 'United States', 'Canada',
#        'India', 'Hong Kong', 'United Arab Emirates', 'Brunei', 'Taiwan',
#        'Papua New Guinea', 'Malaysia', 'Thailand', 'Indonesia', 'Fiji',
#        'Solomon Islands', 'Japan', 'South Korea', 'Chile', 'Mauritius',
#        'Vanuatu', 'Cook Islands', 'Nauru', 'Philippines', 'New Caledonia',
#        'East Timor', 'Vietnam', 'South Africa', 'Qatar', 'Guam', 'Samoa',
#        'Tonga'], dtype=object)

# %%
#Соотнесем с континентами
continent = {'Singapore':'Asia', 'China':'Asia', 'New Zealand':'Oceania', 'United States':'North America', 'Canada':'North America',
       'India':'Asia', 'Hong Kong':'Asia', 'United Arab Emirates':'Asia', 'Brunei':'Asia', 'Taiwan':'Asia',
       'Papua New Guinea':'Oceania', 'Malaysia':'Asia', 'Thailand':'Asia', 'Indonesia':'Asia', 'Fiji':'Oceania',
       'Solomon Islands':'Oceania', 'Japan':'Asia', 'South Korea':'Asia', 'Chile':'South America', 'Mauritius':'Africa',
       'Vanuatu':'Oceania', 'Cook Islands':'Oceania', 'Nauru':'Oceania', 'Philippines':'Asia', 'New Caledonia':'Oceania',
       'Qatar':'Asia', 'East Timor':'Asia', 'Vietnam':'Asia', 'South Africa':'Africa', 'Guam':'Oceania', 'Samoa':'Oceania',
       'Tonga':'Oceania'}

# %%
aus_new['Continent'] = aus_new['Country'].map(continent)
# Out:
# C:\Users\oabek\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
aus_new
# Out:
#     Airline AirlineID SourceAirport Source Airport ID DestinationAirport  \
# 0        3K      3021           DRW              3999                SIN
# 1        3K      3021           PER              3351                SIN
# 2        3U      4608           MEL              3339                CTU
# 3        3U      4608           SYD              3361                CKG
# 4        AA        24           BNE              3320                AKL
# 5        AA        24           BNE              3320                LAX
# 6        AA        24           MEL              3339                LAX
# 7        AA        24           SYD              3361                AKL
# 8        AA        24           SYD              3361                CHC
# 9        AA        24           SYD              3361                DFW
# 10       AA        24           SYD              3361                HNL
# 11       AA        24           SYD              3361                LAX
# 12       AB       214           BNE              3320                SIN
# 13       AC       330           SYD              3361                YVR
# 14       AI       218           MEL              3339                DEL
# 15       AI       218           SYD              3361                DEL
# 16       AY      2350           BNE              3320                HKG
# 17       AY      2350           CNS              3322                HKG
# 18       AY      2350           MEL              3339                HKG
# 19       AY      2350           SYD              3361                HKG
# 20       AZ       596           MEL              3339                AUH
# 21       AZ       596           SYD              3361                AUH
# 22       BA      1355           CNS              3322                HKG
# 23       BA      1355           SYD              3361                SIN
# 24       BI      4255           MEL              3339                BWN
# 25       BR      2091           BNE              3320                TPE
# 26       CA       751           MEL              3339                PVG
# 27       CA       751           SYD              3361                PEK
# 28       CA       751           SYD              3361                PVG
# 29       CG      1308           BNE              3320                POM
# ..      ...       ...           ...               ...                ...
# 305      VA      5360           MEL              3339                AKL
# 306      VA      5360           MEL              3339                AUH
# 307      VA      5360           MEL              3339                CHC
# 308      VA      5360           MEL              3339                DPS
# 309      VA      5360           MEL              3339                LAX
# 310      VA      5360           MEL              3339                NAN
# 311      VA      5360           MEL              3339                SIN
# 312      VA      5360           MEL              3339                WLG
# 313      VA      5360           OOL              3321                AKL
# 314      VA      5360           OOL              3321                CHC
# 315      VA      5360           PER              3351                AKL
# 316      VA      5360           PER              3351                DPS
# 317      VA      5360           PER              3351                HKT
# 318      VA      5360           PER              3351                SIN
# 319      VA      5360           PHE              3349                DPS
# 320      VA      5360           SYD              3361                AKL
# 321      VA      5360           SYD              3361                APW
# 322      VA      5360           SYD              3361                AUH
# 323      VA      5360           SYD              3361                CHC
# 324      VA      5360           SYD              3361                DPS
# 325      VA      5360           SYD              3361                HKG
# 326      VA      5360           SYD              3361                HNL
# 28                  China           Asia
# 29       Papua New Guinea        Oceania
# ..                    ...            ...
# 305           New Zealand        Oceania
# 306  United Arab Emirates           Asia
# 307           New Zealand        Oceania
# 308             Indonesia           Asia
# 309         United States  North America
# 310                  Fiji        Oceania
# 311             Singapore           Asia
# 312           New Zealand        Oceania
# 313           New Zealand        Oceania
# 314           New Zealand        Oceania
# 315           New Zealand        Oceania
# 316             Indonesia           Asia
# 317              Thailand           Asia
# 318             Singapore           Asia
# 319             Indonesia           Asia
# 320           New Zealand        Oceania
# 321                 Samoa        Oceania
# 322  United Arab Emirates           Asia
# 323           New Zealand        Oceania
# 324             Indonesia           Asia
# 325             Hong Kong           Asia
# 326         United States  North America
# 327         United States  North America
# 328                  Fiji        Oceania
# 329             Singapore           Asia
# 330                 Tonga        Oceania
# 331           New Zealand        Oceania
# 332               Vietnam           Asia
# 333               Vietnam           Asia
# 334             Hong Kong           Asia
#
# [334 rows x 11 columns]

# %%
final2 = aus_new.pivot_table(values = 'Airline', index=['Continent', 'Country','DestinationAirport'],  columns='SourceAirport', aggfunc='count')
final2.sort_index()
# Out:
# SourceAirport                                          ADL  BNE  CNS  DRW  \
# Continent     Country              DestinationAirport
# Africa        Mauritius            MRU                 NaN  NaN  NaN  NaN
#               South Africa         JNB                 NaN  NaN  NaN  NaN
# Asia          Brunei               BWN                 NaN  NaN  NaN  NaN
#               China                CAN                 NaN  1.0  NaN  NaN
#                                    CKG                 NaN  NaN  NaN  NaN
#                                    CTU                 NaN  NaN  NaN  NaN
#                                    NKG                 NaN  NaN  NaN  NaN
#                                    PEK                 NaN  NaN  NaN  NaN
#                                    PVG                 NaN  NaN  NaN  NaN
#               East Timor           DIL                 NaN  NaN  NaN  2.0
#               Hong Kong            HKG                 1.0  3.0  3.0  NaN
#               India                DEL                 NaN  NaN  NaN  NaN
#               Indonesia            CGK                 NaN  NaN  NaN  NaN
#                                    DPS                 2.0  3.0  NaN  2.0
#                                    LOP                 NaN  NaN  NaN  NaN
#               Japan                KIX                 NaN  NaN  3.0  NaN
#                                    NRT                 NaN  NaN  3.0  NaN
#               Malaysia             BKI                 NaN  NaN  NaN  NaN
#                                    KUL                 2.0  1.0  NaN  1.0
#               Philippines          MNL                 NaN  NaN  NaN  1.0
#               Qatar                DOH                 NaN  NaN  NaN  NaN
#               Singapore            SIN                 3.0  9.0  NaN  4.0
#               South Korea          ICN                 NaN  1.0  NaN  NaN
#               Taiwan               TPE                 NaN  2.0  NaN  NaN
#               Thailand             BKK                 NaN  2.0  NaN  NaN
#                                    HKT                 NaN  NaN  NaN  NaN
#               United Arab Emirates AUH                 NaN  NaN  NaN  NaN
#                                    DXB                 2.0  2.0  NaN  NaN
#               Vietnam              SGN                 NaN  NaN  NaN  NaN
# North America Canada               YVR                 NaN  NaN  NaN  NaN
#               United States        DFW                 NaN  NaN  NaN  NaN
#                                    HNL                 NaN  1.0  NaN  NaN
#                                    LAX                 NaN  4.0  NaN  NaN
#                                    SFO                 NaN  NaN  NaN  NaN
# Oceania       Cook Islands         RAR                 NaN  NaN  NaN  NaN
#               Nauru                INU                 NaN  NaN  NaN  NaN
#               New Caledonia        NOU                 NaN  NaN  NaN  NaN
#               New Zealand          AKL                 8.0  1.0  3.0  3.0
#                                    CHC                 4.0  NaN  3.0  NaN
#                                    DUD                 NaN  NaN  NaN  NaN
#                                    WLG                 5.0  NaN  NaN  NaN
#                                    ZQN                 1.0  NaN  NaN  NaN
#               Papua New Guinea     POM                 NaN  NaN  NaN  NaN
#                                    RAB                 NaN  NaN  NaN  NaN
#               Samoa                APW                 NaN  NaN  NaN  NaN
#               Solomon Islands      HIR                 NaN  NaN  NaN  NaN
#               Tonga                TBU                 NaN  NaN  NaN  NaN
#               Vanuatu              SON                 NaN  NaN  NaN  NaN
#                                    VLI                 NaN  NaN  NaN  NaN
# South America Chile                SCL                 NaN  NaN  NaN  NaN
#
# SourceAirport                                          PHE   SYD
# Continent     Country              DestinationAirport
# Africa        Mauritius            MRU                 NaN   NaN
#               South Africa         JNB                 NaN   2.0
# Asia          Brunei               BWN                 NaN   NaN
#               China                CAN                 NaN   1.0
#                                    CKG                 NaN   1.0
#                                    CTU                 NaN   NaN
#                                    NKG                 NaN   2.0
#                                    PEK                 NaN   1.0
#                                    PVG                 NaN   4.0
#               East Timor           DIL                 NaN   NaN
#               Hong Kong            HKG                 NaN   5.0
#               India                DEL                 NaN   1.0
#               Indonesia            CGK                 NaN   2.0
#                                    DPS                 1.0   3.0
#                                    LOP                 NaN   NaN
#               Japan                KIX                 NaN   NaN
#                                    NRT                 NaN   2.0
#               Malaysia             BKI                 NaN   NaN
#                                    KUL                 NaN   2.0
#               Philippines          MNL                 NaN   2.0
#               Qatar                DOH                 NaN   NaN
#               Singapore            SIN                 NaN   9.0
#               South Korea          ICN                 NaN   4.0
#               Taiwan               TPE                 NaN   1.0
#               Thailand             BKK                 NaN   4.0
#                                    HKT                 NaN   1.0
#               United Arab Emirates AUH                 NaN   3.0
#                                    DXB                 NaN   2.0
#               Vietnam              SGN                 NaN   2.0
# North America Canada               YVR                 NaN   1.0
#               United States        DFW                 NaN   2.0
#                                    HNL                 NaN   5.0
#                                    LAX                 NaN   6.0
#                                    SFO                 NaN   2.0
# Oceania       Cook Islands         RAR                 NaN   1.0
#               Fiji                 NAN                 NaN   4.0
#                                    SUV                 NaN   1.0
#               Guam                 GUM                 NaN   NaN
#               Nauru                INU                 NaN   NaN
#               New Caledonia        NOU                 NaN   2.0
#               New Zealand          AKL                 NaN  11.0
#                                    CHC                 NaN   7.0
#                                    DUD                 NaN   NaN
#                                    WLG                 NaN   5.0
#                                    ZQN                 NaN   3.0
#               Papua New Guinea     POM                 NaN   2.0
#                                    RAB                 NaN   NaN
#               Samoa                APW                 NaN   1.0
#               Solomon Islands      HIR                 NaN   NaN
#               Tonga                TBU                 NaN   1.0
#               Vanuatu              SON                 NaN   NaN
#                                    VLI                 NaN   2.0
# South America Chile                SCL                 NaN   2.0

# %%
airport[airport['IATA']=='DOH']
# Out:
# Empty DataFrame
# Columns: [ID, Name, City, Country, IATA, ICAO, Latitude, Longitude, Altitude, Timezone, DST, Tz database time zone, Type, Source]
# Index: []
